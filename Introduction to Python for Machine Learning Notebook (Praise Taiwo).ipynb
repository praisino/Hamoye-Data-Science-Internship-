# %% [markdown]
# # Creating and Manipulating Datasets

# %%
# Import important libraries
import numpy as np
import pandas as pd

# %% [markdown]
# ##### NUMPY

# %%
# create a list
arr = [6,7,8,9]
arr
print(type(arr))
# Out:
# <class 'list'>

# %%
# convert a list to a numpy array and check its properties
a = np.array(arr)
print(type(a))
print(a.shape)
print(a.dtype)
print(a.ndim)
# Out:
# <class 'numpy.ndarray'>
# (4,)
# int32
# 1

# %%
# create multi dimensional numpy arrays and slice through them
d = np.array([[4.0,5.0,6.0],[7.0,8.0,9.0]])
print(d)
print (d.dtype ,d.ndim)
d[1, 0:3]
# Out:
# [[4. 5. 6.]
#  [7. 8. 9.]]
# float64 2
# array([7., 8., 9.])

# %%
# creating more than  dimensional array
b = np.array([['Kunle',14,50000,5],['lekan',24,54000,2],['Nnamdi',30,100000,3], ['Juliet',54,12000,4], ['Dave',28,90000,4]])
print (d.dtype ,d.ndim)
b
# Out:
# float64 2
# array([['Kunle', '14', '50000', '5'],
#        ['lekan', '24', '54000', '2'],
#        ['Nnamdi', '30', '100000', '3'],
#        ['Juliet', '54', '12000', '4'],
#        ['Dave', '28', '90000', '4']], dtype='<U6')

# %%
# create a random array
c = np.random.random((2,3))
print(c)
d = np.full((2,3), 4)
print(d)
# Out:
# [[0.5709968  0.03876499 0.88614848]
#  [0.81935595 0.69943848 0.85371582]]
# [[4 4 4]
#  [4 4 4]]

# %% [markdown]
# ##### PANDAS

# %%
# convert from numpy array to pandas dataframe
customer_details = pd.DataFrame(b, columns=['Names','Age', 'Monthly_Income','No_of_Kids'], index=[1,2,3,4,5])
customer_details
# Out:
#     Names Age Monthly_Income No_of_Kids
# 1   Kunle  14          50000          5
# 2   lekan  24          54000          2
# 3  Nnamdi  30         100000          3
# 4  Juliet  54          12000          4
# 5    Dave  28          90000          4

# %%
# slicing and quering through he dataframe
print (customer_details.iloc[3])
print ("#" * 30)
print (customer_details.loc[4])
print ("#" * 30)
print (customer_details.iloc[3, 1])
print (customer_details.loc[4, 'Age'])
# Out:
# Names             Juliet
# Age                   54
# Monthly_Income     12000
# No_of_Kids             4
# Name: 4, dtype: object
# ##############################
# Names             Juliet
# Age                   54
# Monthly_Income     12000
# No_of_Kids             4
# Name: 4, dtype: object
# ##############################
# 54
# 54

# %%
customer_details['Age']
# Out:
# 1    14
# 2    24
# 3    30
# 4    54
# 5    28
# Name: Age, dtype: object

# %%
print (customer_details.at[5, 'No_of_Kids'])
print (customer_details.iat[4, 1])
# Out:
# 4
# 28

# %%
# convert type of 'Age' column from object to integer
print (customer_details['Age'].dtype)
customer_details['Age'] = customer_details['Age'].astype(int) # conversion
print (customer_details['Age'].dtype)
# Out:
# object
# int32

# %%
# creating a new dataset from scratch using pandas
e = pd.DataFrame([['Kunle',14,50000,5],['lekan',24,54000,2],['Nnamdi',30,100000,3], ['Juliet',54,120000,4], ['Dave',28,90000,4]], columns=['Names','Age', 'Monthly_Income','No_of_Kids'], index=[1,2,3,4,5])
e
# Out:
#     Names  Age  Monthly_Income  No_of_Kids
# 1   Kunle   14           50000           5
# 2   lekan   24           54000           2
# 3  Nnamdi   30          100000           3
# 4  Juliet   54          120000           4
# 5    Dave   28           90000           4

# %%
e.sum()
# Out:
# Names             KunlelekanNnamdiJulietDave
# Age                                      150
# Monthly_Income                        414000
# No_of_Kids                                18
# dtype: object

# %%
e.describe()
# Out:
#              Age  Monthly_Income  No_of_Kids
# count   5.000000        5.000000    5.000000
# mean   30.000000    82800.000000    3.600000
# std    14.764823    30152.943472    1.140175
# min    14.000000    50000.000000    2.000000
# 25%    24.000000    54000.000000    3.000000
# 50%    28.000000    90000.000000    4.000000
# 75%    30.000000   100000.000000    4.000000
# max    54.000000   120000.000000    5.000000

# %%
# creating an array and converting to a dataframe whilst labeling the indices
daylist = np.array(['monday', 'tuesday', 'wednesday', 'thursday', 'friday'])
daylist = pd.Series(daylist,  index=['a','b','c', 'd', 'e'])
daylist
# Out:
# a       monday
# b      tuesday
# c    wednesday
# d     thursday
# e       friday
# dtype: object

# %%
print (daylist.loc['c'])
print (daylist.iloc[2])
# Out:
# wednesday
# wednesday

# %% [markdown]
# # Data Wrangling and Visualization

# %%
# download dataframe
url = 'https://github.com/WalePhenomenon/climate_change/blob/master/fuel_ferc1.csv?raw=true'
fuel_data = pd.read_csv(url, error_bad_lines=False)
fuel_data.describe(include='all')
# Out:
#                       record_id  utility_id_ferc1   report_year  \
# count                     29523      29523.000000  29523.000000
# unique                    29523               NaN           NaN
# top     f1_fuel_2007_12_41_1_11               NaN           NaN
# freq                          1               NaN           NaN
# mean                        NaN        118.601836   2005.806050
# std                         NaN         74.178353      7.025483
# min                         NaN          1.000000   1994.000000
# 25%                         NaN         55.000000   2000.000000
# 50%                         NaN        122.000000   2006.000000
# 75%                         NaN        176.000000   2012.000000
# max                         NaN        514.000000   2018.000000
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# count             29523               29523     29343     2.952300e+04
# ...

# %%
# preview the top and last five rows in the datasets
print (fuel_data.head())
print ('+' * 100)
fuel_data.tail()
# Out:
#                 record_id  utility_id_ferc1  report_year  \
# 0   f1_fuel_1994_12_1_0_7                 1         1994
# 1  f1_fuel_1994_12_1_0_10                 1         1994
# 2   f1_fuel_1994_12_2_0_1                 2         1994
# 3   f1_fuel_1994_12_2_0_7                 2         1994
# 4  f1_fuel_1994_12_2_0_10                 2         1994
#
#        plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0              rockport                coal       ton        5377489.0
# 1  rockport total plant                coal       ton       10486945.0
# 2                gorgas                coal       ton        2978683.0
# 3                 barry                coal       ton        3739484.0
# 4             chickasaw                 gas       mcf          40533.0
#
#    fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# 0               16.590                      18.59
# 1               16.592                      18.58
# ...

# %% [markdown]
# ##### HANDLING NULL VALUES

# %%
# check for null values
fuel_data.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
(180/29343) * 100
# Out:
# 0.6134342091810653

# %%
# preview the fuel_unit column
print(fuel_data['fuel_unit'].describe()) 
fuel_data.groupby('fuel_unit')['fuel_unit'].count()
# Out:
# count     29343
# unique        9
# top         mcf
# freq      11354
# Name: fuel_unit, dtype: object
# fuel_unit
# bbl        7998
# gal          84
# gramsU      464
# kgU         110
# mcf       11354
# mmbtu       180
# mwdth        95
# mwhth       100
# ton        8958
# Name: fuel_unit, dtype: int64

# %%
# replace the null values with the most occured unique value (fuel_unit) 'mcf'
fuel_data[['fuel_unit']] = fuel_data[['fuel_unit']].fillna(value='mcf')
fuel_data['fuel_unit'].isnull().sum()
# Out:
# 0

# %%
sns.barplot
# Out:
# <function seaborn.categorical.barplot(x=None, y=None, hue=None, data=None, order=None, hue_order=None, estimator=<function mean at 0x000001BF0BED3D38>, ci=95, n_boot=1000, units=None, seed=None, orient=None, color=None, palette=None, saturation=0.75, errcolor='.26', errwidth=None, capsize=None, dodge=True, ax=None, **kwargs)>

# %% [markdown]
# ##### DATA SPLITTING

# %%
# Split fuel_data
fuel_df1 = fuel_data.iloc[0:19000].reset_index(drop=True)
fuel_df2 = fuel_data.iloc[19000:].reset_index(drop=True)

# %%
# print fuel_df2 to check its content
fuel_df2
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0       f1_fuel_2009_12_79_0_2                79         2009
# 1       f1_fuel_2009_12_79_0_4                79         2009
# 2       f1_fuel_2009_12_79_0_5                79         2009
# 3       f1_fuel_2009_12_79_0_7                79         2009
# 4      f1_fuel_2009_12_79_0_10                79         2009
# ...                        ...               ...          ...
# 10518  f1_fuel_2018_12_12_0_13                12         2018
# 10519   f1_fuel_2018_12_12_1_1                12         2018
# 10520  f1_fuel_2018_12_12_1_10                12         2018
# 10521  f1_fuel_2018_12_12_1_13                12         2018
# 10522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  montrose                 oil       bbl          22912.0
# ...

# %%
# check if the total items in the table is same with the splitted dataframes fuel_df1 and fuel df2
print (len(fuel_df1) + len(fuel_df2), len(fuel_data))
len(fuel_data) == (len(fuel_df1) + len(fuel_df2))
# Out:
# 29523 29523
# True

# %%
# print fuel_df2 to check its content
fuel_df2.head()
# Out:
#                  record_id  utility_id_ferc1  report_year plant_name_ferc1  \
# 0   f1_fuel_2009_12_79_0_2                79         2009         montrose
# 1   f1_fuel_2009_12_79_0_4                79         2009       hawthorn 5
# 2   f1_fuel_2009_12_79_0_5                79         2009       hawthorn 5
# 3   f1_fuel_2009_12_79_0_7                79         2009   hawthorn 6 & 9
# 4  f1_fuel_2009_12_79_0_10                79         2009   hawthorn 7 & 8
#
#   fuel_type_code_pudl fuel_unit  fuel_qty_burned  fuel_mmbtu_per_unit  \
# 0                 oil       bbl          22912.0             5.770422
# 1                coal       ton        2408123.0            16.782000
# 2                 gas       mcf          82141.0             1.000000
# 3                 gas       mcf        1701680.0             1.000000
# 4                 gas       mcf          82601.0             1.000000
#
#    fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# ...

# %%
# join the original fuel data to fuel_df1 to create duplicate items
fuel_data_duplicate = pd.concat([fuel_data, fuel_df1]).reset_index(drop=True)

# %%
# check for duplicates
fuel_data_duplicate.duplicated().any()
# Out:
# True

# %% [markdown]
# ##### DATA VISUALIZATION

# %%
# Import plotting library
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# plot graph
plt.figure(figsize=(7,4))
plt.xticks(rotation=90)
fuel_unit = pd.DataFrame({'unit':['BBL', 'GAL', 'GRAMSU', 'KGU', 'MCF', 'MMBTU', 'MWDTH', 'MWHTH', 'TON'],
            'count':[7998, 84, 464, 110, 11354, 180, 95, 100, 8958]})
sns.barplot(data=fuel_unit, x='unit', y='count')
plt.xlabel('Fuel Unit')
# Out:
# Text(0.5, 0, 'Fuel Unit')

# %%
# plot in log format to accomodate the extreme large data
g = sns.barplot(data=fuel_unit, x='unit', y='count')
g.set_yscale("log")
g.set_ylim(1, 12000)
plt.xlabel('Fuel Unit')
# Out:
# Text(0.5, 0, 'Fuel Unit')

# %%
# select part of the dataset
sample_df = fuel_data.sample(n=50, random_state=4)
len(sample_df)

sns.regplot(sample_df['utility_id_ferc1'], y = sample_df['fuel_cost_per_mmbtu'], fit_reg=True)

# %%
# Box plot
sns.boxplot(x="fuel_type_code_pudl", y="utility_id_ferc1",
            palette=["m", "g"], data=fuel_data)

# %%
fuel_data
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
fuel_data['report_year'] = fuel_data['report_year'].astype(int)
# fuel_data['report_year']
fuel_data.groupby('fuel_type_code_pudl')['report_year'].describe()
# Out:
#                        count         mean       std     min      25%     50%  \
# fuel_type_code_pudl
# coal                  8547.0  2004.623143  7.137389  1994.0  1998.00  2004.0
# gas                  11486.0  2005.978060  7.280214  1994.0  1999.25  2006.0
# nuclear                818.0  2002.970660  7.155665  1994.0  1997.00  2001.0
# oil                   8064.0  2007.195933  6.140652  1994.0  2003.00  2007.0
# other                  167.0  2001.700599  5.712505  1994.0  1997.00  2000.0
# waste                  441.0  2005.650794  7.460231  1994.0  1998.00  2006.0
#
#                         75%     max
# fuel_type_code_pudl
# coal                 2011.0  2018.0
# gas                  2012.0  2018.0
# nuclear              2008.0  2018.0
# oil                  2012.0  2018.0
# other                2006.0  2016.0
# waste                2012.0  2018.0

# %%
sns.lineplot(x='fuel_type_code_pudl', y=('report_year'), data=fuel_data)
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-191-86a16999f07f> in <module>
# ----> 1 sns.lineplot(y='fuel_type_code_pudl', x=('report_year'), data=fuel_data)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#    1135         ax = plt.gca()
#    1136
# -> 1137     p.plot(ax, kwargs)
#    1138     return ax
#    1139
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\relational.py in plot(self, ax, kws)
#     812                     err = "estimator must be None when specifying units"
#     813                     raise ValueError(err)
# --> 814                 x, y, y_ci = self.aggregate(y, x, units)
# ...

# %%
sns.barplot(x='fuel_type_code_pudl', y='fuel_cost_per_unit_burned', data=fuel_data)

# %%
fuel_data.corr()
# Out:
#                               utility_id_ferc1  fuel_qty_burned  \
# utility_id_ferc1                      1.000000        -0.057447
# fuel_qty_burned                      -0.057447         1.000000
# fuel_mmbtu_per_unit                  -0.066946        -0.080946
# fuel_cost_per_unit_burned            -0.037863        -0.018535
# fuel_cost_per_unit_delivered         -0.016414        -0.003551
# fuel_cost_per_mmbtu                   0.006122        -0.001896
#
#                               fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# utility_id_ferc1                        -0.066946                  -0.037863
# fuel_qty_burned                         -0.080946                  -0.018535
# fuel_mmbtu_per_unit                      1.000000                  -0.010034
# fuel_cost_per_unit_burned               -0.010034                   1.000000
# fuel_cost_per_unit_delivered            -0.009039                   0.011007
# ...

# %%
fuel_data.groupby('report_year')['fuel_cost_per_unit_delivered'].describe()
# Out:
#               count          mean            std      min      25%      50%  \
# report_year
# 1994         1235.0     63.636060    1288.748659  -58.800  2.32600  13.1560
# 1995         1201.0     32.735269     173.849821  -85.640  1.80600   5.1140
# 1996         1088.0   9196.705948  244767.437600  -44.050  2.93500  16.2700
# 1997         1094.0  11140.197239  256945.853368  -38.972  2.94650  14.4515
# 1998         1107.0    287.154420    8172.214382  -43.747  2.40000   3.4750
# 1999         1050.0     25.551627     137.826776  -32.970  2.52700   3.5750
# 2000         1373.0    985.362877   31576.526616 -174.670  4.37000  19.4700
# 2001         1356.0     60.050396     947.767770  -37.790  4.35950  21.2150
# 2002         1205.0     47.594361     906.266622  -60.290  3.72400  17.8940
# 2003         1211.0     55.663493     996.166868 -118.340  5.93000  21.9670
# 2004         1192.0    139.524275    3848.790040 -313.410  6.51500  20.9000
# ...

# %%
fuel_data.groupby('fuel_cost_per_unit_burned').describe()
# Out:
#                           utility_id_ferc1                                  \
#                                      count   mean std    min    25%    50%
# fuel_cost_per_unit_burned
# -276.080                               1.0  194.0 NaN  194.0  194.0  194.0
# -174.670                               1.0  194.0 NaN  194.0  194.0  194.0
# -123.310                               1.0  194.0 NaN  194.0  194.0  194.0
# -119.040                               1.0  281.0 NaN  281.0  281.0  281.0
# -85.760                                1.0  194.0 NaN  194.0  194.0  194.0
# ...                                    ...    ...  ..    ...    ...    ...
#  65137.588                             1.0    7.0 NaN    7.0    7.0    7.0
#  69785.215                             1.0    7.0 NaN    7.0    7.0    7.0
#  80459.000                             1.0  177.0 NaN  177.0  177.0  177.0
#  83538.000                             1.0  132.0 NaN  132.0  132.0  132.0
# ...

# %%
fuel_data['fuel_mmbtu_per_unit'].describe()
# Out:
# count    29523.000000
# mean         8.492111
# std         10.600220
# min          0.000001
# 25%          1.024000
# 50%          5.762694
# 75%         17.006000
# max        341.260000
# Name: fuel_mmbtu_per_unit, dtype: float64

# %%
# Determine Kurtosis and Skewness
K_FuelQ = fuel_data['fuel_qty_burned'].kurtosis()
S_FuelQ = fuel_data['fuel_qty_burned'].skew()
print (k_FuelQ, S_FuelQ)
# Out:
# 651.3694501337732 15.851495469109503
